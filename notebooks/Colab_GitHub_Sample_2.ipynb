# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitaGuptaIndia/Coursera_Colab_Github_demo/blob/main/notebooks/Colab_GitHub_Sample_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AnkitaGuptaIndia/Coursera_Colab_Github_demo.git
# Out:
# Cloning into 'Coursera_Colab_Github_demo'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 29 (delta 8), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 135.39 KiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# %cd Coursera_Colab_Github_demo
# Out:
# /content/Coursera_Colab_Github_demo

# %%
# !ls
# Out:
# Colab_GitHub_Sample_2.ipynb  notebooks	README.md  sample.csv

# %%
import pandas as pd

df = pd.read_csv("notebooks/train.csv")
df.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
df_save_sample = df.head()
df_save_sample
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
df_save_sample.to_csv("notebooks/train_sample.csv", index=False)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	notebooks/train_sample.csv
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git config --global user.email "ankitagpt32.ag@gmail.com"

# %%
# !git config --global user.name "AnkitaGuptaIndia"

# %%
# !git commit -m "Added sample CSV file"
# Out:
# [main de2ee6d] Added sample CSV file
#  1 file changed, 6 insertions(+)
#  create mode 100644 notebooks/train_sample.csv

# %%
# !git push <token URL>
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 548 bytes | 274.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/AnkitaGuptaIndia/Coursera_Colab_Github_demo.git
#    21d002b..de2ee6d  main -> main
