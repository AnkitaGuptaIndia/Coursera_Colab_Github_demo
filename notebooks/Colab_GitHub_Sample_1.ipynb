# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitaGuptaIndia/Coursera_Colab_Github_demo/blob/main/notebooks/Colab_GitHub_Sample_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Check if the file is correctly linked to Github

# %%
print("Hello, this file is saved to GitHub")
# Out:
# Hello, this file is saved to GitHub

# %%
print("This is additional step in Colab.")
# Out:
# This is additional step in Colab.

# %% [markdown]
# ## Connect with Github and save a csv file in Github account directly

# %%
# !git clone https://github.com/AnkitaGuptaIndia/Coursera_Colab_Github_demo.git
# Out:
# Cloning into 'Coursera_Colab_Github_demo'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.

# %%
# %cd Coursera_Colab_Github_demo
# Out:
# /content/Coursera_Colab_Github_demo

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["A", "B", "C"],
    "score": [10, 20, 30]
})

df.to_csv("sample.csv", index=False)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	sample.csv
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git config --global user.email "ankitagpt32.ag@gmail.com"

# %%
# !git config --global user.name "AnkitaGuptaIndia"

# %%
# !git commit -m "Added sample CSV file"
# Out:
# [main 6b5ab59] Added sample CSV file
#  1 file changed, 4 insertions(+)
#  create mode 100644 sample.csv

# %%
# !git push <token URL>

# %% [markdown]
# ## Connect with Github and read a csv file in Github account directly

# %%
# !git clone https://github.com/AnkitaGuptaIndia/Coursera_Colab_Github_demo.git
# Out:
# Cloning into 'Coursera_Colab_Github_demo'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 3), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 130.42 KiB | 2.33 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# !ls
# Out:
# Coursera_Colab_Github_demo  notebooks  README.md  sample.csv

# %%
# %cd Coursera_Colab_Github_demo
# Out:
# /content/Coursera_Colab_Github_demo/Coursera_Colab_Github_demo

# %%
# !ls
# Out:
# notebooks  README.md  sample.csv

# %%
df = pd.read_csv("notebooks/train.csv")
df.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert
